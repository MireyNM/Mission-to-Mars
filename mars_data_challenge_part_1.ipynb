# %%
# Imports

import json
import pandas as pd


from splinter import Browser
from bs4 import BeautifulSoup as soup
from webdriver_manager.chrome import ChromeDriverManager

# Set up Browser with Splinter
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)

# %%
# Have the browser navigate to the website and copy the content
url = 'https://redplanetscience.com/'
browser.visit(url)
html = browser.html
soup = soup(html, 'html.parser')

# %%
# Preview HTML code
soup
# Out:
# <html><head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link crossorigin="anonymous" href="https://cdn.jsdelivr.net/npm/bootstrap@5.0.0-beta1/dist/css/bootstrap.min.css" integrity="sha384-giJF6kkoqNQ00vy+HMDP7azOuL0xtbfIcaT9wjKHr8RbDVddVHyTfAAsrekwKmP1" rel="stylesheet"/>
# <link href="css/font.css" rel="stylesheet" type="text/css"/>
# <link href="css/app.css" rel="stylesheet" type="text/css"/>
# <link crossorigin="anonymous" href="https://pro.fontawesome.com/releases/v5.10.0/css/all.css" integrity="sha384-AYmEC3Yw5cVb3ZcuHtOA93w35dYTsvhLPVnYs9eStHfGJvOvKxVfELGroGkvsg+p" rel="stylesheet"/>
# <title>News - Mars Exploration Program</title>
# </head>
# <body>
# <div class="col-md-12">
# <div class="row">
# <nav class="navbar navbar-expand-lg navbar-light fixed-top">
# <div class="container-fluid">
# <a class="navbar-brand" href="#">
# <img src="image/nasa.png" width="80"/><span class="logo">MARS Planet Science</span>
# ...

# %%
#Scrapping the title text for each article
titles=soup.find_all('div',class_='content_title')

a=1
for title in titles:
    print(a,".",title.text)
    a=a+1
# Out:
# 1 . NASA's Treasure Map for Water Ice on Mars
# 2 . NASA Wins Two Emmy Awards for Interactive Mission Coverage
# 3 . My Culture, My Voice
# 4 . NASA's Perseverance Rover Goes Through Trials by Fire, Ice, Light and Sound
# 5 . NASA's Perseverance Rover Will Carry First Spacesuit Materials to Mars
# 6 . Deadline Closing for Names to Fly on NASA's Next Mars Rover
# 7 . Scientists Explore Outback as Testbed for Mars
# 8 . NASA Invites Students to Name Mars 2020 Rover
# 9 . Common Questions about InSight's 'Mole'
# 10 . NASA's Mars Helicopter Attached to Mars 2020 Rover
# 11 . NASA Invites Public to Share Excitement of Mars 2020 Perseverance Rover Launch
# 12 . Virginia Middle School Student Earns Honor of Naming NASA's Next Mars Rover
# 13 . With Mars Methane Mystery Unsolved, Curiosity Serves Scientists a New One: Oxygen
# 14 . Two of a Space Kind: Apollo 12 and Mars 2020
# 15 . NASA's Mars 2020 Heads Into the Test Chamber

# %%
#Scrapping the Summary text for each article
summaries= soup.find_all('div', class_='article_teaser_body')

b=1
for summary in summaries:
    print(b,'.',summary.text)
    b=b+1
# Out:
# 1 . A new study identifies frozen water just below the Martian surface, where astronauts could easily dig it up.
# 2 . NASA-JPL's coverage of the Mars InSight landing earns one of the two wins, making this the NASA center's second Emmy.
# 3 . In honor of Hispanic Heritage Month, Christina Hernandez, an instrument engineer on the Mars 2020 mission, talks about her childhood and journey to NASA.
# 4 . The agency's new Mars rover is put through a series of tests in vacuum chambers, acoustic chambers and more to get ready for the Red Planet.
# 5 . In a Q&A, spacesuit designer Amy Ross explains how five samples, including a piece of helmet visor, will be tested aboard the rover, which is targeting a July 30 launch.
# 6 . You have until Sept. 30 to send your names to Mars aboard the Mars 2020 rover.
# 7 . Australia provides a great place for NASA's Mars 2020 and the ESA-Roscosmos ExoMars scientists to hone techniques in preparation for searching for signs ancient life on Mars.
# ...

# %% [markdown]
# ## Putting everything together

# %%
# Slide_elem is the parent element that holds all the elements within it
slide_elem = soup.find_all('div',class_='list_text')

# Itereate through all the element to scrap the titles and the summary for each article
mars_list = []
for elem in slide_elem:
    mars_data={"title":"","preview":""}
    title=elem.find_all('div',class_='content_title')
    summary= elem.find_all('div', class_='article_teaser_body')
    mars_data["title"] = title[0].text
    mars_data["preview"] = summary[0].text
    mars_list.append(mars_data)
print(mars_list)
# Out:
# [{'title': "NASA Readies Perseverance Mars Rover's Earthly Twin ", 'preview': "Did you know NASA's next Mars rover has a nearly identical sibling on Earth for testing? Even better, it's about to roll for the first time through a replica Martian landscape."}, {'title': "Mars Helicopter Attached to NASA's Perseverance Rover", 'preview': "The team also fueled the rover's sky crane to get ready for this summer's history-making launch."}, {'title': "NASA's Perseverance Rover Bringing 3D-Printed Metal Parts to Mars", 'preview': "For hobbyists and makers, 3D printing expands creative possibilities; for specialized engineers, it's also key to next-generation spacecraft design."}, {'title': 'MOXIE Could Help Future Rockets Launch Off Mars', 'preview': "NASA's Perseverance rover carries a device to convert Martian air into oxygen that, if produced on a larger scale, could be used not just for breathing, but also for fuel."}, {'title': "NASA's Mars Perseverance Rover Gets Its Sample Handling Sy
# ...

# %%
# Export Python list to JSON file
json_mars = json.dumps(mars_list)
print(json_mars)
# Out:
# [{"title": "NASA Readies Perseverance Mars Rover's Earthly Twin ", "preview": "Did you know NASA's next Mars rover has a nearly identical sibling on Earth for testing? Even better, it's about to roll for the first time through a replica Martian landscape."}, {"title": "Mars Helicopter Attached to NASA's Perseverance Rover", "preview": "The team also fueled the rover's sky crane to get ready for this summer's history-making launch."}, {"title": "NASA's Perseverance Rover Bringing 3D-Printed Metal Parts to Mars", "preview": "For hobbyists and makers, 3D printing expands creative possibilities; for specialized engineers, it's also key to next-generation spacecraft design."}, {"title": "MOXIE Could Help Future Rockets Launch Off Mars", "preview": "NASA's Perseverance rover carries a device to convert Martian air into oxygen that, if produced on a larger scale, could be used not just for breathing, but also for fuel."}, {"title": "NASA's Mars Perseverance Rover Gets Its Sample Handling Sy
# ...

# %%
# Save json as csv file
df=pd.read_json(json_mars)
df.to_csv('mars.csv',index=False)
